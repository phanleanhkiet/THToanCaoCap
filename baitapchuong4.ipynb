# %% [markdown]
# <a href="https://colab.research.google.com/github/phanleanhkiet/THToanCaoCap/blob/main/baitapchuong4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# th1

# %%
import numpy as np
mienchia=np.linspace(0,2,11)
print(mienchia)
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2. ]

# %% [markdown]
# th2

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,1000)
t=all_time[:100]
for f in fs:
  y = np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))
plt.legend()
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/Thuchanhchuong4/basic-python.pdf')
plt.show()
# Out:
# Mounted at /drive

# %% [markdown]
# th3

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
fig, ax =plt.subplots()
for f in fs:
  y = np.sin(2*np.pi*f*t)
  ax.plot(t,y,label='{}Hz'.format(f))
plt.legend()
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/Thuchanhchuong4/basic-python.pdf')
plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
for f in fs:
  y = np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))
plt.legend()
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/Thuchanhchuong4/basic-python.pdf')
plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# th4

# %%
def f (x):return x**2
print (f(8))
# Out:
# 64

# %%
g=lambda x: x**2
print(g(4))
# Out:
# 16

# %% [markdown]
# th5

# %%
def thue(phan_tram):return lambda x:x*phan_tram
hcm=thue(0.012)
hn=thue(0.01)
print(hcm(1000000))
print(hn(1000000))
# Out:
# 12000.0
# 10000.0

# %% [markdown]
# th6

# %%
hinhthang =lambda f,a,b:(b-a)*(f(a)+f(b))/2
from math import exp
hinhthang(exp,0,1)
def hai_x (x):
  return 2*x
print(hinhthang(hai_x,1,2))
# Out:
# 3.0

# %% [markdown]
# th 9

# %%
from sympy import intergal ,symbol
x=symbol('x')
k=symbol('k')
intergal(k*x,x)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-2e53a72fdd54> in <module>()
# ----> 1 from sympy import intergal ,symbol
#       2 x=symbol('x')
#       3 k=symbol('k')
#       4 intergal(k*x,x)
#
# ImportError: cannot import name 'intergal' from 'sympy' (/usr/local/lib/python3.7/dist-packages/sympy/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# th10

# %%
from sympy import Integral

F=Integral(k*x,x).doit()
print(F)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-e5300291ce0a> in <module>()
#       1
# ----> 2 from sympy import Integral,symbol
#       3 x=symbol('x')
#       4 k=symbol('k')
#       5 F=Integral(k*x,x).doit()
#
# ImportError: cannot import name 'symbol' from 'sympy' (/usr/local/lib/python3.7/dist-packages/sympy/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# th11

# %%
intergal(k*x,(x,0,2)).doit()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-34e546b661ea> in <module>()
# ----> 1 from sympy import intergal
#       2
#       3 intergal(k*x,(x,0,2)).doit()
#
# ImportError: cannot import name 'intergal' from 'sympy' (/usr/local/lib/python3.7/dist-packages/sympy/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
